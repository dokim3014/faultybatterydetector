# %%
import numpy as np
import matplotlib.pyplot as plt

from lib import tally

dimension = (200, 200, 1)
image_3d = tally.usrbin(r"C:\Users\user\Documents\KakaoTalk Downloads\battery\gen_normal\output\res1_run001_fort.22", dimension)
image_2d = image_3d[:,:,0]

plt.imshow(image_2d, cmap="gray")
plt.colorbar()
plt.xlabel("y pixel index")
plt.ylabel("x pixel index")
plt.show()

# %%
print(type(image_2d), image_2d.max(), image_2d.min(), image_2d.mean())
# Out:
# <class 'numpy.ndarray'> 0.0006725565 0.0002087303 0.00057138776
